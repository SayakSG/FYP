# %%
from ultralytics import YOLO

model=YOLO('yolov8x')
result = model.track("input_videos/input_video.mp4",save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/214) C:\Users\sayaseng\Downloads\HackathonProject\input_videos\input_video.mp4: 384x640 8 persons, 2 tennis rackets, 2 chairs, 2 clocks, 1163.3ms
# video 1/1 (frame 2/214) C:\Users\sayaseng\Downloads\HackathonProject\input_videos\input_video.mp4: 384x640 8 persons, 2 tennis rackets, 2 chairs, 2 clocks, 1105.5ms
# ...
